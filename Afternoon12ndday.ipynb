# %%
import numpy as np
import pandas as pd

# %%
rank = pd.Series(['ace',2,3,4,5,6,7,8,9,10,'jack','queen','king'])

# %%
suit= pd.Series(['heart','spades','clubs','diamonds'])

# %%
deck=pd.merge(rank.rename('rank').to_frame(),suit.rename('suit').to_frame (), how='cross')
deck
# Out:
#      rank      suit
# 0     ace     heart
# 1     ace    spades
# 2     ace     clubs
# 3     ace  diamonds
# 4       2     heart
# 5       2    spades
# 6       2     clubs
# 7       2  diamonds
# 8       3     heart
# 9       3    spades
# 10      3     clubs
# 11      3  diamonds
# 12      4     heart
# 13      4    spades
# 14      4     clubs
# 15      4  diamonds
# 16      5     heart
# 17      5    spades
# 18      5     clubs
# 19      5  diamonds
# 20      6     heart
# 21      6    spades
# 22      6     clubs
# 23      6  diamonds
# 24      7     heart
# 25      7    spades
# 26      7     clubs
# 27      7  diamonds
# 28      8     heart
# 29      8    spades
# 30      8     clubs
# 31      8  diamonds
# 32      9     heart
# 33      9    spades
# 34      9     clubs
# 35      9  diamonds
# 36     10     heart
# 37     10    spades
# 38     10     clubs
# 39     10  diamonds
# 40   jack     heart
# 41   jack    spades
# 42   jack     clubs
# 43   jack  diamonds
# 44  queen     heart
# 45  queen    spades
# 46  queen     clubs
# 47  queen  diamonds
# 48   king     heart
# 49   king    spades
# 50   king     clubs
# 51   king  diamonds

# %%
def get_new_deck():
    rank = pd.Series(['ace',2,3,4,5,6,7,8,9,10,'jack','queen','king'])
    suit= pd.Series(['heart','spades','clubs','diamonds'])
    deck=pd.merge(rank.rename('rank').to_frame(),suit.rename('suit').to_frame (), how='cross')
    return deck

# %%
#we drew a hand but did not remove the cards from dek 
deck= get_new_deck()
hand = deck.sample (2,replace=False)
hand
# Out:
#      rank    suit
# 1     ace  spades
# 46  queen   clubs

# %%
#to remove the cards from the deck 
def draw_cards (n,deck):
        drawn=deck.sample (n,replace=False)
        deck= deck.drop(drawn.index)

        return drawn,deck

# %%
deck.drop(hand.index,axis='rows')
# Out:
#      rank      suit
# 0     ace     heart
# 2     ace     clubs
# 3     ace  diamonds
# 4       2     heart
# 5       2    spades
# 6       2     clubs
# 7       2  diamonds
# 8       3     heart
# 9       3    spades
# 10      3     clubs
# 11      3  diamonds
# 12      4     heart
# 13      4    spades
# 14      4     clubs
# 15      4  diamonds
# 16      5     heart
# 17      5    spades
# 18      5     clubs
# 19      5  diamonds
# 20      6     heart
# 21      6    spades
# 22      6     clubs
# 23      6  diamonds
# 24      7     heart
# 25      7    spades
# 26      7     clubs
# 27      7  diamonds
# 28      8     heart
# 29      8    spades
# 30      8     clubs
# 31      8  diamonds
# 32      9     heart
# 33      9    spades
# 34      9     clubs
# 35      9  diamonds
# 36     10     heart
# 37     10    spades
# 38     10     clubs
# 39     10  diamonds
# 40   jack     heart
# 41   jack    spades
# 42   jack     clubs
# 43   jack  diamonds
# 44  queen     heart
# 45  queen    spades
# 47  queen  diamonds
# 48   king     heart
# 49   king    spades
# 50   king     clubs
# 51   king  diamonds

# %%
deck
# Out:
#      rank      suit
# 0     ace     heart
# 1     ace    spades
# 2     ace     clubs
# 3     ace  diamonds
# 4       2     heart
# 5       2    spades
# 6       2     clubs
# 7       2  diamonds
# 8       3     heart
# 9       3    spades
# 10      3     clubs
# 11      3  diamonds
# 12      4     heart
# 13      4    spades
# 14      4     clubs
# 15      4  diamonds
# 16      5     heart
# 17      5    spades
# 18      5     clubs
# 19      5  diamonds
# 20      6     heart
# 21      6    spades
# 22      6     clubs
# 23      6  diamonds
# 24      7     heart
# 25      7    spades
# 26      7     clubs
# 27      7  diamonds
# 28      8     heart
# 29      8    spades
# 30      8     clubs
# 31      8  diamonds
# 32      9     heart
# 33      9    spades
# 34      9     clubs
# 35      9  diamonds
# 36     10     heart
# 37     10    spades
# 38     10     clubs
# 39     10  diamonds
# 40   jack     heart
# 41   jack    spades
# 42   jack     clubs
# 43   jack  diamonds
# 44  queen     heart
# 45  queen    spades
# 46  queen     clubs
# 47  queen  diamonds
# 48   king     heart
# 49   king    spades
# 50   king     clubs
# 51   king  diamonds

# %%
hand_size = 5
deck = get_new_deck()
while len(deck) > hand_size:
    hand,deck = draw_cards(hand_size, deck)
    print(len(deck))
# Out:
# 47
# 42
# 37
# 32
# 27
# 22
# 17
# 12
# 7
# 2

# %%
deck
# Out:
#    rank      suit
# 15    4  diamonds
# 39   10  diamonds

# %%
#set index 
#so saying has 2 rows no column since assigned as index
deck.set_index (['rank','suit']).shape
# Out:
# (2, 0)

# %%
#rules of scoring, score is zero to start with. 
def score_hand(hand):
    score=0
    aces=hand.loc[hand['rank']=="ace"]
    rest = hand.loc[hand['rank'] !='ace']

    for _i, card in rest.iterrows():
        if type(card['rank']) == int:
            score+=card['rank']

        elif type (card['rank'])==str:
            score +=10
    for _i, card in aces.iterrows():
        if score+11 > 21:
            score+=1
        else:
            score +=11

    return score

# %%
hand
# Out:
#     rank      suit
# 4      2     heart
# 9      3    spades
# 50  king     clubs
# 49  king    spades
# 51  king  diamonds

# %%
score_hand(hand)
# Out:
# 35

# %%
score = 0
while True:
    score+=3
    if score >50:
        break
    #will not be executed on the last loop

# %%
score
# Out:
# 51

# %%
deck = get_new_deck ()
running_Score= 0
while len(deck)>hand_size:
    hand,deck = draw_cards (hand_size,deck)
    if "ace" in hand ['rank']:
        continue 
    running_Score += score_hand (hand)

# %%
while True:
    if True:
        pass
    if False: 
        pass
    #this will go indefintly unless I stop
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 while True:
#       2     if True:
#       3         pass
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt

# %%
num_trials = 50

trial_results = []

for i in range (num_trials):
    deck = get_new_deck()
    score= play_hand(deck)
    trial_results.append (score)

plt.hist (trial_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       5 for i in range (num_trials):
#       6     deck = get_new_deck()
# ----> 7     score= play_hand(deck)
#       8     trial_results.append (score)
#      10 plt.hist (trial_results)
#
# NameError: name 'play_hand' is not defined

# %%
def play_hand (deck):
    hand,deck = draw_cards(2, deck)
    
    #write here 
    #define whether you take an extra card
    condition = False
    if score <=10 
         condition = True
    while condition:
         drawn_card, deck = draw_cards(1,deck)
        hand = pd.concat([hand,drawn_card])
    if condition >=17
        condition = False


score = score_hand (hand)
if score>21:
    score=0
return score
# Out:
#   File <tokenize>:11
#     hand = pd.concat([hand,drawn_card])
#     ^
# IndentationError: unindent does not match any outer indentation level
